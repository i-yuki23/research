# %%
import sys
import json
sys.path.append('..')
from lib.plot import plot_learning_curve
from lib.path import get_hist_path
from lib.result_analysis import show_max_validation_values

# %%
DATA_TYPE = 'valid_all/smoothing/gr'
DATA_VOXEL_NUM = 20
CLASSIFYING_RULE = 'WaterClassifyingRuleEmbedding'
LIGAND_POCKET_DEFINER = 'LigandPocketDefinerOriginal'
LIGAND_VOXEL_NUM = 8
MODEL_NAME = 'ResNet'
TRAINER_NAME = 'aug_train'

# %%
hist_path = get_hist_path(DATA_TYPE, DATA_VOXEL_NUM, CLASSIFYING_RULE, LIGAND_POCKET_DEFINER, LIGAND_VOXEL_NUM, MODEL_NAME, TRAINER_NAME)

# %%
with open(hist_path, 'r') as f:
    history = json.load(f)

# %%
len(history['accuracy'])
# Out:
# 167

# %%
120-80,117-77,167-127

# %%
plot_learning_curve(history)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 plot_learning_curve(history)
#
# File ~/research/src/analysis/../lib/plot.py:149, in plot_learning_curve(hist, title_fontsize, fontsize)
#     147 # バリデーションデータのプロット
#     148 val_key = f'val_{key}'
# --> 149 plt.plot(hist[val_key], label=f'Validation {key}')
#     150 plt.title(f'Training and Validation {key.capitalize()}', fontsize=title_fontsize)
#     151 plt.xlabel('Epochs',  fontsize=title_fontsize)
#
# KeyError: 'val_learning_rate'

# %%
max_metrics = show_max_validation_values(history)
# Out:
# Minimum val_loss: 0.5793366432189941
# Maximum val_accuracy: 0.6942909955978394
# Maximum val_dice_coefficient: 0.687821626663208
# Maximum val_recall: 0.8913809061050415
# Maximum val_precision: 0.7860438227653503
