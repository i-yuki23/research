# %%
import sys
import json
sys.path.append('..')
from lib.plot import plot_learning_curve
from lib.path import get_hist_path
from lib.result_analysis import show_max_validation_values

# %%
DATA_TYPE = 'gr_Protein'
DATA_VOXEL_NUM = 10
CLASSIFYING_RULE = 'WaterClassifyingRuleSurface'
LIGAND_POCKET_DEFINER = 'LigandPocketDefinerOriginal'
LIGAND_VOXEL_NUM = 8
MODEL_NAME = 'ResNet_gelu'

# %%
hist_path = get_hist_path(DATA_TYPE, DATA_VOXEL_NUM, CLASSIFYING_RULE, LIGAND_POCKET_DEFINER, LIGAND_VOXEL_NUM, MODEL_NAME)

# %%
with open(hist_path, 'r') as f:
    history = json.load(f)

# %%
plot_learning_curve(history)

# %%
max_metrics = show_max_validation_values(history)
# Out:
# Minimum val_loss: 0.589541494846344
# Maximum val_accuracy: 0.6937094330787659
# Maximum val_dice_coefficient: 0.6587882041931152
# Maximum val_recall: 0.7746061086654663
# Maximum val_precision: 0.7353990077972412
